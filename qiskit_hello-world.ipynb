# %% [markdown]
# # Hello world example on a 2-qubit bell state
#
# ## 1. Map problem to circuits and operators

# %%
from qiskit import QuantumCircuit

qc = QuantumCircuit(2)

qc.h(0)
qc.cx(0,1)
qc.draw(output='mpl')

# %%
from qiskit.quantum_info import Pauli

ZZ = Pauli('ZZ')
ZI = Pauli('ZI')
IZ = Pauli('IZ')
XX = Pauli('XX')
XI = Pauli('XI')
IX = Pauli('IX')

observables = (ZZ, ZI, IZ, XX, XI, IX)

# %% [markdown]
# ## 2. Execute on backend

# %%
from qiskit_aer.primitives import Estimator

estimator = Estimator()

job = estimator.run([qc]*len(observables), observables)

job.result()
# Out:
# EstimatorResult(values=array([ 1.        ,  0.05664062,  0.05664062,  1.        , -0.03515625,
#        -0.03515625]), metadata=[{'shots': 1024, 'variance': 0.0, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.000359292, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1], 'device': 'CPU', 'time_taken': 0.001834041, 'measure_sampling': True, 'num_clbits': 2, 'max_memory_mb': 16384, 'input_qubit_map': [[1, 1], [0, 0]], 'num_qubits': 2, 'method': 'stabilizer', 'required_memory_mb': 0, 'fusion': {'enabled': False}}]}, {'shots': 1024, 'variance': 0.9967918395996094, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.000359292, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1], 'device': 'CPU', 'time_taken': 0.001834041, 'measure_sampling': True, 'num_clbits': 2, 'max_memory_mb': 16384, 'input_qubit_map': [[1, 1], [0, 0]], 'num_qubits': 2, 'method': 'stabilizer', 'required_memory_mb': 0, 'fusion': {'enabled': False}}]}, {'shots': 1024, 'variance': 0.9967918395996094, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.000359292, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1], 'device': 'CPU', 'time_taken': 0.001834041, 'measure_sampling': True, 'num_clbits': 2, 'max_memory_mb': 16384, 'input_qubit_map': [[1, 1], [0, 0]], 'num_qubits': 2, 'method': 'stabilizer', 'required_memory_mb': 0, 'fusion': {'enabled': False}}]}, {'shots': 1024, 'variance': 0.0, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.000411959, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1], 'device': 'CPU', 'time_taken': 0.001202709, 'measure_sampling': True, 'num_clbits': 2, 'max_memory_mb': 16384, 'input_qubit_map': [[1, 1], [0, 0]], 'num_qubits': 2, 'method': 'stabilizer', 'required_memory_mb': 0, 'fusion': {'enabled': False}}]}, {'shots': 1024, 'variance': 0.9987640380859375, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.000411959, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1], 'device': 'CPU', 'time_taken': 0.001202709, 'measure_sampling': True, 'num_clbits': 2, 'max_memory_mb': 16384, 'input_qubit_map': [[1, 1], [0, 0]], 'num_qubits': 2, 'method': 'stabilizer', 'required_memory_mb': 0, 'fusion': {'enabled': False}}]}, {'shots': 1024, 'variance': 0.9987640380859375, 'simulator_metadata': [{'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.000411959, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0, 1], 'device': 'CPU', 'time_taken': 0.001202709, 'measure_sampling': True, 'num_clbits': 2, 'max_memory_mb': 16384, 'input_qubit_map': [[1, 1], [0, 0]], 'num_qubits': 2, 'method': 'stabilizer', 'required_memory_mb': 0, 'fusion': {'enabled': False}}]}])

# %% [markdown]
# ## 3. Post-process and plot

# %%
import matplotlib.pyplot as plt

data = ['ZZ', 'ZI', 'IZ', 'XX', 'XI', 'IX']
values = job.result().values

plt.plot(data, values, '-o')
plt.xlabel('Observables')
plt.ylabel('Expectation value')
plt.show()

# %% [markdown]
# # Extend Hellow World example to an $n$-qubit GHZ state
#
# ## 1. Map the problem to circuits and operators

# %%
def get_qc_for_n_qubit_GHZ_state(n):
    qc = QuantumCircuit(n)
    qc.h(0)
    for i in range(n-1):
        qc.cx(i, i-1)
    return qc

n = 10
qc = get_qc_for_n_qubit_GHZ_state(n)
qc.draw(output='mpl')

# %%
from qiskit.quantum_info import SparsePauliOp

operator_strings = ['Z' + 'I' * i + 'Z' + 'I' * (n-2-i) for i in range(n-1)]
print(operator_strings)
print(len(operator_strings))

operators = [SparsePauliOp(operator_string) for operator_string in operator_strings]
# Out:
# ['ZZIIIIIIII', 'ZIZIIIIIII', 'ZIIZIIIIII', 'ZIIIZIIIII', 'ZIIIIZIIII', 'ZIIIIIZIII', 'ZIIIIIIZII', 'ZIIIIIIIZI', 'ZIIIIIIIIZ']
# 9

# %% [markdown]
# ## 2. Optimize for quantum execution

# %%
from qiskit_ibm_runtime import QiskitRuntimeService
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager

backend = QiskitRuntimeService().least_busy(operational=True, simulator=False)
pass_manager = generate_preset_pass_manager(optimization_level=1, backend=backend)

qc_transpiled = pass_manager.run(qc)
operators_transpiled_list = [op.apply_layout(qc_transpiled.layout) for op in operators]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 5
#       2 from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
#       4 backend = QiskitRuntimeService().least_busy(operational=True, simulator=False)
# ----> 5 pass_manager = generate_preset_pass_manager(optimization_level=1, backend=backend)
#       7 qc_transpiled = pass_manager.run(qc)
#       8 operators_transpiled_list = [op.apply_layout(qc_transpiled.layout) for op in operators]
#
# File /opt/miniconda3/envs/qiskit/lib/python3.12/site-packages/qiskit/transpiler/preset_passmanagers/__init__.py:275, in generate_preset_pass_manager(optimization_level, backend, target, basis_gates, inst_map, coupling_map, instruction_durations, backend_properties, timing_constraints, initial_layout, layout_method, routing_method, translation_method, scheduling_method, approximation_degree, seed_transpiler, unitary_synthesis_method, unitary_synthesis_plugin_config, hls_config, init_method, optimization_method, _skip_target)
#     273 if backend is not None:
#     274     pm_options["_skip_target"] = _skip_target
# --> 275     pm_config = PassManagerConfig.from_backend(backend, **pm_options)
#     276 else:
#     277     pm_config = PassManagerConfig(**pm_options)
#
# File /opt/miniconda3/envs/qiskit/lib/python3.12/site-packages/qiskit/transpiler/passmanager_config.py:135, in PassManagerConfig.from_backend(cls, backend, _skip_target, **pass_manager_options)
#     133         res.basis_gates = getattr(config, "basis_gates", None)
#     134     else:
# --> 135         res.basis_gates = backend.operation_names
#     136 if res.inst_map is None:
#     137     if backend_version < 2:
#
# File /opt/miniconda3/envs/qiskit/lib/python3.12/site-packages/qiskit/providers/backend.py:382, in BackendV2.operation_names(self)
#     379 @property
#     380 def operation_names(self) -> List[str]:
#     381     """A list of instruction names that the backend supports."""
# --> 382     return list(self.target.operation_names)
#
# File /opt/miniconda3/envs/qiskit/lib/python3.12/site-packages/qiskit_ibm_runtime/ibm_backend.py:337, in IBMBackend.target(self)
#     330 @property
#     331 def target(self) -> Target:
#     332     """A :class:`qiskit.transpiler.Target` object for the backend.
#     333
#     334     Returns:
#     335         Target
#     336     """
# --> 337     self._get_properties(datetime=python_datetime.now())
#     338     self._get_defaults()
#     339     self._convert_to_target(refresh=True)
#
# File /opt/miniconda3/envs/qiskit/lib/python3.12/site-packages/qiskit_ibm_runtime/ibm_backend.py:246, in IBMBackend._get_properties(self, datetime)
#     244     datetime = local_to_utc(datetime)
#     245 if datetime or not self._properties:
# --> 246     api_properties = self._api_client.backend_properties(self.name, datetime=datetime)
#     247     if api_properties:
#     248         backend_properties = properties_from_server_data(api_properties)
#
# File /opt/miniconda3/envs/qiskit/lib/python3.12/site-packages/qiskit_ibm_runtime/api/clients/runtime.py:337, in RuntimeClient.backend_properties(self, backend_name, datetime)
#     322 def backend_properties(
#     323     self, backend_name: str, datetime: Optional[python_datetime] = None
#     324 ) -> Dict[str, Any]:
#     325     """Return the properties of the IBM backend.
#     326
#     327     Args:
#    (...)
#     335         NotImplementedError: If `datetime` is specified.
#     336     """
# --> 337     return self._api.backend(backend_name).properties(datetime=datetime)
#
# File /opt/miniconda3/envs/qiskit/lib/python3.12/site-packages/qiskit_ibm_runtime/api/rest/cloud_backend.py:64, in CloudBackend.properties(self, datetime)
#      61 if datetime:
#      62     params["updated_before"] = datetime.isoformat()
# ---> 64 response = self.session.get(url, params=params).json()
#      65 # Adjust name of the backend.
#      66 if response:
#
# File /opt/miniconda3/envs/qiskit/lib/python3.12/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File /opt/miniconda3/envs/qiskit/lib/python3.12/site-packages/qiskit_ibm_runtime/api/session.py:328, in RetrySession.request(self, method, url, bare, **kwargs)
#     326 try:
#     327     self._log_request_info(final_url, method, kwargs)
# --> 328     response = super().request(method, final_url, headers=headers, **kwargs)
#     329     response.raise_for_status()
#     330 except RequestException as ex:
#     331     # Wrap the requests exceptions into a IBM Q custom one, for
#     332     # compatibility.
#
# File /opt/miniconda3/envs/qiskit/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/miniconda3/envs/qiskit/lib/python3.12/site-packages/requests/sessions.py:746, in Session.send(self, request, **kwargs)
#     743         pass
#     745 if not stream:
# --> 746     r.content
#     748 return r
#
# File /opt/miniconda3/envs/qiskit/lib/python3.12/site-packages/requests/models.py:902, in Response.content(self)
#     900         self._content = None
#     901     else:
# --> 902         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     904 self._content_consumed = True
#     905 # don't need to release the connection; that's been handled by urllib3
#     906 # since we exhausted the data.
#
# File /opt/miniconda3/envs/qiskit/lib/python3.12/site-packages/requests/models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File /opt/miniconda3/envs/qiskit/lib/python3.12/site-packages/urllib3/response.py:1057, in HTTPResponse.stream(self, amt, decode_content)
#    1041 """
#    1042 A generator wrapper for the read() method. A call will block until
#    1043 ``amt`` bytes have been read from the connection or until the
#    (...)
#    1054     'content-encoding' header.
#    1055 """
#    1056 if self.chunked and self.supports_chunked_reads():
# -> 1057     yield from self.read_chunked(amt, decode_content=decode_content)
#    1058 else:
#    1059     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
#
# File /opt/miniconda3/envs/qiskit/lib/python3.12/site-packages/urllib3/response.py:1206, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1203     amt = None
#    1205 while True:
# -> 1206     self._update_chunk_length()
#    1207     if self.chunk_left == 0:
#    1208         break
#
# File /opt/miniconda3/envs/qiskit/lib/python3.12/site-packages/urllib3/response.py:1125, in HTTPResponse._update_chunk_length(self)
#    1123 if self.chunk_left is not None:
#    1124     return None
# -> 1125 line = self._fp.fp.readline()  # type: ignore[union-attr]
#    1126 line = line.split(b";", 1)[0]
#    1127 try:
#
# File /opt/miniconda3/envs/qiskit/lib/python3.12/socket.py:708, in SocketIO.readinto(self, b)
#     706 while True:
#     707     try:
# --> 708         return self._sock.recv_into(b)
#     709     except timeout:
#     710         self._timeout_occurred = True
#
# File /opt/miniconda3/envs/qiskit/lib/python3.12/ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/miniconda3/envs/qiskit/lib/python3.12/ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## 3. Execute on the backend

# %%
from qiskit_ibm_runtime import EstimatorV2 as Estimator
from qiskit_ibm_runtime import EstimatorOptions

options = EstimatorOptions()
options.resilience_level = 1
options.optimization_level = 0
options.dynamical_decoupling.sequence_type = "XY4"

estimator = Estimator(backend, options=options)
job = estimator.run([(qc_transpiled, operators_transpiled_list)])
job_id = job.job_id()
print(job_id)
# Out:
# ctyqw6g5yns0008s6yng

# %% [markdown]
# ## 4. Post-process and plot

# %%
job_id = 'ctyqw6g5yns0008s6yng'
service = QiskitRuntimeService()
job = service.job(job_id)

import matplotlib.pyplot as plot

data = list(range(1, len(operators)+1))
result = job.result()[0]
values = result.data.evs
values = [v / values[0] for v in values]

plt.scatter(data, values, marker='o', label='100-qubit GHZ state')
plt.xlabel('Distance between qubits $i$')
plt.ylabel(r'$\langle Z_0 Z_i \rangle / \langle Z_0 Z_1 \rangle$')
plt.legend()
plt.show()
